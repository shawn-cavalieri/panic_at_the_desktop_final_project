# %%
import pandas as pd
import datetime
import numpy as np
import pandas_datareader.data as web
from pandas import Series, DataFrame


start = datetime.datetime(2020, 1, 1)
end = datetime.datetime(2020, 5, 1)

df = web.DataReader("AAPL", 'yahoo', start, end)
df.head(10)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02  300.600006  295.190002  296.239990  300.350006  33870100.0
# 2020-01-03  300.579987  296.500000  297.149994  297.429993  36580700.0
# 2020-01-06  299.959991  292.750000  293.790009  299.799988  29596800.0
# 2020-01-07  300.899994  297.480011  299.839996  298.390015  27218000.0
# 2020-01-08  304.440002  297.160004  297.160004  303.190002  33019800.0
# 2020-01-09  310.429993  306.200012  307.239990  309.630005  42527100.0
# 2020-01-10  312.670013  308.250000  310.600006  310.329987  35161200.0
# 2020-01-13  317.070007  311.149994  311.640015  316.959991  30383000.0
# 2020-01-14  317.570007  312.170013  316.700012  312.679993  40488600.0
# 2020-01-15  315.500000  309.549988  311.850006  311.339996  30480900.0
#
#              Adj Close
# Date
# 2020-01-02  299.638885
# 2020-01-03  296.725769
# 2020-01-06  299.090149
# 2020-01-07  297.683533
# 2020-01-08  302.472137
# 2020-01-09  308.896912
# 2020-01-10  309.595215
# 2020-01-13  316.209534
# 2020-01-14  311.939667
# 2020-01-15  310.602844

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
price_data = df[['High','Low','Open','Close','Volume','Adj Close']]


# calculate the change in price
price_data['change_in_price'] = price_data['Adj Close'].diff()

# %%
price_data.isnull().sum()

# %%
price_data.head(10)

# %%
up_df, down_df = price_data[['change_in_price']].copy(), price_data[['change_in_price']].copy()

# For up days, if the change is less than 0 set to 0.
up_df.loc['change_in_price'] = up_df.loc[(up_df['change_in_price'] < 0), 'change_in_price'] = 0

# For down days, if the change is greater than 0 set to 0.
down_df.loc['change_in_price'] = down_df.loc[(down_df['change_in_price'] > 0), 'change_in_price'] = 0

# We need change in price to be absolute.
down_df['change_in_price'] = down_df['change_in_price'].abs()

# %%
price_data['down_days'] = down_df['change_in_price']
price_data['up_days'] = up_df['change_in_price']

# %%
price_data
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02  300.600006  295.190002  296.239990  300.350006  33870100.0
# 2020-01-03  300.579987  296.500000  297.149994  297.429993  36580700.0
# 2020-01-06  299.959991  292.750000  293.790009  299.799988  29596800.0
# 2020-01-07  300.899994  297.480011  299.839996  298.390015  27218000.0
# 2020-01-08  304.440002  297.160004  297.160004  303.190002  33019800.0
# ...                ...         ...         ...         ...         ...
# 2020-04-27  284.540009  279.950012  281.799988  283.170013  29271900.0
# 2020-04-28  285.829987  278.200012  285.079987  278.579987  28001200.0
# 2020-04-29  289.670013  283.890015  284.730011  287.730011  34320200.0
# 2020-04-30  294.529999  288.350006  289.959991  293.799988  45766000.0
# 2020-05-01  299.000000  285.850006  286.250000  289.070007  60154200.0
#
#              Adj Close  change_in_price  down_days   up_days
# Date
# 2020-01-02  299.638885              NaN        NaN       NaN
# 2020-01-03  296.725769        -2.913116   2.913116  0.000000
# 2020-01-06  299.090149         2.364380   0.000000  2.364380
# 2020-01-07  297.683533        -1.406616   1.406616  0.000000
# 2020-01-08  302.472137         4.788605   0.000000  4.788605
# ...                ...              ...        ...       ...
# 2020-04-27  283.170013         0.200012   0.000000  0.200012
# 2020-04-28  278.579987        -4.590027   4.590027  0.000000
# 2020-04-29  287.730011         9.150024   0.000000  9.150024
# 2020-04-30  293.799988         6.069977   0.000000  6.069977
# 2020-05-01  289.070007        -4.729980   4.729980  0.000000
#
# [84 rows x 9 columns]

# %%
# We need to remove all rows that have an NaN value.
print('Before NaN Drop we have {} rows and {} columns'.format(price_data.shape[0], price_data.shape[1]))

# Any row that has a `NaN` value will be dropped.
price_data = price_data.dropna()

# Display how much we have left now.
print('After NaN Drop we have {} rows and {} columns'.format(price_data.shape[0], price_data.shape[1]))

# Print the head.
price_data.head()
# Out:
# Before NaN Drop we have 84 rows and 9 columns
# After NaN Drop we have 83 rows and 9 columns
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-03  300.579987  296.500000  297.149994  297.429993  36580700.0
# 2020-01-06  299.959991  292.750000  293.790009  299.799988  29596800.0
# 2020-01-07  300.899994  297.480011  299.839996  298.390015  27218000.0
# 2020-01-08  304.440002  297.160004  297.160004  303.190002  33019800.0
# 2020-01-09  310.429993  306.200012  307.239990  309.630005  42527100.0
#
#              Adj Close  change_in_price  down_days   up_days
# Date
# 2020-01-03  296.725769        -2.913116   2.913116  0.000000
# 2020-01-06  299.090149         2.364380   0.000000  2.364380
# 2020-01-07  297.683533        -1.406616   1.406616  0.000000
# 2020-01-08  302.472137         4.788605   0.000000  4.788605
# 2020-01-09  308.896912         6.424774   0.000000  6.424774

# %%
# Add a new column named 'Prediction' 
price_data['Prediction'] = [0 if x < 0 else 1 for x in price_data['change_in_price']]
# Out:
# C:\Users\adibc\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
price_data.head(30)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-03  300.579987  296.500000  297.149994  297.429993  36580700.0
# 2020-01-06  299.959991  292.750000  293.790009  299.799988  29596800.0
# 2020-01-07  300.899994  297.480011  299.839996  298.390015  27218000.0
# 2020-01-08  304.440002  297.160004  297.160004  303.190002  33019800.0
# 2020-01-09  310.429993  306.200012  307.239990  309.630005  42527100.0
# 2020-01-10  312.670013  308.250000  310.600006  310.329987  35161200.0
# 2020-01-13  317.070007  311.149994  311.640015  316.959991  30383000.0
# 2020-01-14  317.570007  312.170013  316.700012  312.679993  40488600.0
# 2020-01-15  315.500000  309.549988  311.850006  311.339996  30480900.0
# 2020-01-16  315.700012  312.089996  313.589996  315.239990  27207300.0
# 2020-01-17  318.739990  315.000000  316.269989  318.730011  34454100.0
# 2020-01-21  319.019989  316.000000  317.190002  316.570007  27710800.0
# 2020-01-22  319.989990  317.309998  318.579987  317.700012  25458100.0
# 2020-02-13  324.869995        -2.330017   2.330017   0.000000           0
# 2020-02-14  324.950012         0.080017   0.000000   0.080017           1

# %%
X_Cols = price_data[['High','Low','Open','Close','Volume','Adj Close','change_in_price', 'down_days', 'up_days']]
Y_Cols = price_data['Prediction']

X_train, X_test, y_train, y_test = train_test_split(X_Cols, Y_Cols, random_state = 0)

# Create a random forest Classifier
r_f_c = RandomForestClassifier(n_estimators = 100, oob_score = True, criterion = 'gini', random_state = 0)

# Fitting the model
r_f_c.fit(X_train, y_train)

# Make predictions
y_pred = r_f_c.predict(X_test)

# %%
# Print the accuracy of the model 
print('Correct Prediction (%):', accuracy_score(y_test, y_pred, normalize = True) * 100.0)
# Out:
# Correct Prediction (%): 95.23809523809523

# %%
#Checking Count of each value
positive_true_count = len(price_data.loc[price_data['Prediction'] == 1])
negative_true_count = len(price_data.loc[price_data['Prediction'] == 0])

# %%
#Get true count of positive and Negative
(positive_true_count, negative_true_count)
# Out:
# (39, 44)

# %% [markdown]
# # Classification Report

# %%
# Define the traget names
target_names = ['Down Day', 'Up Day']

# Build a classifcation report
report = classification_report(y_true = y_test, y_pred = y_pred, target_names = target_names, output_dict = True)

# Add it to a data frame, transpose it for readability.
report_df = pd.DataFrame(report).transpose()
report_df
# Out:
#               precision    recall  f1-score    support
# Down Day       1.000000  0.900000  0.947368  10.000000
# Up Day         0.916667  1.000000  0.956522  11.000000
# accuracy       0.952381  0.952381  0.952381   0.952381
# macro avg      0.958333  0.950000  0.951945  21.000000
# weighted avg   0.956349  0.952381  0.952163  21.000000

# %% [markdown]
# # Calculating Feature Importance and Graphing

# %%
# Calculate feature importance and store in pandas series
feature_imp = pd.Series(r_f_c.feature_importances_, index=X_Cols.columns).sort_values(ascending=False)
feature_imp
# Out:
# change_in_price    0.361765
# down_days          0.300440
# up_days            0.284271
# Volume             0.013213
# Close              0.013003
# Adj Close          0.010211
# Low                0.007424
# Open               0.005110
# High               0.004563
# dtype: float64

# %%
import matplotlib.pyplot as plt

imp_featuredf = pd.DataFrame(feature_imp)
imp_featuredf
# Out:
#                         0
# change_in_price  0.361765
# down_days        0.300440
# up_days          0.284271
# Volume           0.013213
# Close            0.013003
# Adj Close        0.010211
# Low              0.007424
# Open             0.005110
# High             0.004563

# %%
imp_featuredf['Features']=imp_featuredf.index
maindf = imp_featuredf.reset_index(drop=True)

# %%
maindf.rename(columns={0: "Percentage"})
# Out:
#    Percentage         Features
# 0    0.361765  change_in_price
# 1    0.300440        down_days
# 2    0.284271          up_days
# 3    0.013213           Volume
# 4    0.013003            Close
# 5    0.010211        Adj Close
# 6    0.007424              Low
# 7    0.005110             Open
# 8    0.004563             High

# %%
maindf.set_index('Features', inplace=True)

# %%
maindf.plot(kind='bar',legend=None)
plt.title("Features affecting Model and their Importances(out of 1%)")
plt.xlabel('Features')
plt.ylabel('Percentage(%)')
plt.grid()
plt.savefig("FeaturesAndImp.png")
plt.show()
